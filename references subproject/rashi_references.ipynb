# %%
masechtot=[]
with open('/Users/ephraimmeiri/Documents/רשי research docs/references subproject/שמות מסכתות.txt') as f:
    data = f.read()
    masechtot = data.split(', ')

# %%
masechtot
# Out:
# ['ברכות',
#  'פאה',
#  'דמאי',
#  'כלאים',
#  'שביעית',
#  'תרומות',
#  'מעשרות',
#  'מעשר שני',
#  'מע"ש',
#  'חלה',
#  'ערלה',
#  'ביכורים',
#  'שבת',
#  'עירובין',
#  'פסחים',
#  'שקלים',
#  'ראש השנה',
#  'ר"ה',
#  'יומא',
#  'סדר יומא',
#  'סוכה',
#  'ביצה',
#  'תענית',
#  'מגילה',
#  'מועד קטן',
#  'משקין',
#  'יבמות',
#  'כתובות',
#  'נדרים',
#  'נזיר',
#  'סוטה',
#  'גיטין',
#  'קידושין',
#  'בבא קמא',
#  'ב"ק',
#  'בבא מציעא',
#  'ב"מ',
#  'בבא בתרא',
#  'ב"ב',
#  'סנהדרין',
#  'מכות',
#  'שבועות',
#  'עבודה זרה',
#  'ע"ז',
#  'הוריות',
#  'עדיות',
#  'אבות',
#  'זבחים',
#  'שחיטת קדשים',
#  'מנחות',
#  'חולין',
#  'שחיטת חולין',
#  'בכורות',
#  'ערכין',
#  'תמורה',
#  'כריתות',
#  'מעילה',
#  'קנים',
#  'תמיד',
#  'מדות',
#  'נדה',
#  'כלים',
#  'אהלות',
#  'נגעים',
#  'פרה',
#  'טהרות',
#  'מקוואות',
#  'מכשירין',
#  'זבים',
#  'טבול יום',
#  'ידים',
#  'עוקצין']

# %%
os.listdir(rashi_dir)
# Out:
# ['Rashi on Bava Kamma.json',
#  'Rashi on Sanhedrin.json',
#  'Rashi on Bava Batra.json',
#  '.DS_Store.json',
#  'Rashi on Avodah Zarah.json',
#  'Rashi on Makkot.json',
#  'Rashi on Yevamot.json',
#  'Rashi on Kiddushin.json',
#  'Rashi on Niddah.json',
#  'Rashi on Pesachim.json',
#  'Rashi on Menachot.json',
#  'Rashi on Sukkah.json',
#  'Rashi on Yoma.json',
#  'Rashi on Sotah.json',
#  'Rashi on Shevuot.json',
#  'Rashi on Temurah.json',
#  'Rashi on Gittin.json',
#  'Rashi on Berakhot.json',
#  'Rashi on Arakhin.json',
#  'Rashi on Chullin.json',
#  'Rashi on Rosh Hashanah.json',
#  'Rashi on Ketubot.json',
#  'Rashi on Zevachim.json',
#  'Rashi on Megillah.json',
#  'Rashi on Beitzah.json',
#  'Rashi on Shabbat.json',
#  'Rashi on Eruvin.json',
#  'Rashi on Bava Metzia.json',
#  'Rashi on Chagigah.json',
#  'Rashi on Keritot.json']

# %%
'כלים' in masechtot
# Out:
# True

# %%
filtered_masechtot = masechtot.copy()
filtered_masechtot.remove("כלים")
filtered_masechtot.remove("ידים")

# %%
def contains_masechet(text):
    results= None
    for masechet in filtered_masechtot:
        if "ב"+masechet in text:
            if results:
                results+=", "
                # print("Multi")
            else:
                results=""
            results+=masechet
    return results

# %%
def contains_perek_Dmasechet(text):
    results= None
    for masechet in filtered_masechtot:
        if "ד"+masechet in text and "פרק" in text:
            if results:
                results+=", "
                # print("Multi")
            else:
                results=""
            results+=masechet
    return results

# %%
def contains_masechet_bPerek(text):
    results= None
    for masechet in filtered_masechtot:
        if "ב"+masechet+" בפרק" in text:
            if results:
                results+=", "
                # print("Multi")
            else:
                results=""
            results+=masechet
    return results

# %%
(len(masechtot),len(filtered_masechtot))
# Out:
# (72, 70)

# %%
sample_text = 'רבי יהודה אומר מטמא - דלא מהניא מליקה לטריפה וה"ה נמי דבשחיטת חולין טריפה פליג ר יהודה וכן שנינו במסכת טהרות בפ יג דברים לרבי יהודה אחת מלוקות ואחת שחוטות ולר"מ שתיהן מטהרות ולרבי יוסי שחיטה מטהרת טריפה אבל לא מליקה:'
contains_masechet(sample_text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [64], line 2
#       1 sample_text = 'רבי יהודה אומר מטמא - דלא מהניא מליקה לטריפה וה"ה נמי דבשחיטת חולין טריפה פליג ר יהודה וכן שנינו במסכת טהרות בפ יג דברים לרבי יהודה אחת מלוקות ואחת שחוטות ולר"מ שתיהן מטהרות ולרבי יוסי שחיטה מטהרת טריפה אבל לא מליקה:'
# ----> 2 contains_masechet(sample_text)
#
# Cell In [63], line 3, in contains_masechet(text)
#       1 def contains_masechet(text):
#       2     results= None
# ----> 3     filtered_masechtot = masechtot.remove("כלים").remove("ידים")
#       4     for masechet in filtered_masechtot:
#       5         if "ב"+masechet in text:
#
# AttributeError: 'NoneType' object has no attribute 'remove'

# %%
results = []
rashi_dir= '/Users/ephraimmeiri/gitEtc/Rashi Thesis work/Rashi plaintext/json undisputed'
file = "Rashi on Zevachim.json"
name = file[9:-5]
print(name)
with open(rashi_dir+"/"+file) as f:
    data = json.load(f)
    for daf,d in zip(data['text'],range(len(data['text']))):
        for line,l in zip(daf,range(len(daf))):
            for comment,c in zip(line,range(len(line))):
                cont = contains_masechet(comment)
                if cont:
                    results.append(((name,cont,d,c),comment))
print(len(results))
# Out:
# Zevachim
# Multi
# Multi
# Multi
# Multi
# Multi
# Multi
# Multi
# Multi
# Multi
# 228

# %%
multis = [ent for ent in results if ", " in ent[0][1]]

# %%
multis
# Out:
# [(('Zevachim', 'סדר יומא, תמיד', 38, 0),
#   'שנים עשר דד - שמוציאין מימיו ואמרינן בסדר יומא שיהו שנים עשר כהנים העסוקים בתמיד מקדשים בבת אחת:'),
#  (('Zevachim', 'נגעים, פרה', 77, 0),
#   'שמעכבות בכל מקום - כדמפרש לקמיה בפרה ובנגעים:'),
#  (('Zevachim', 'סדר יומא, בכורות, תמורה', 96, 0),
#   'קדשים לא חיילי (עליה) - תחילת הקדש אינו חל על בעל מום קבוע ליקדש קדושת הגוף אלא קדושת דמים בעלמא ויוצאין לחולין גמורין בפדיון ואפילו ליגזז וליעבד כדתניא פרק הוציאו לו בסדר יומא (דף נ:) חומר בתמורה שהתמורה חלה על בעל מום קבוע ואין יוצא לחולין ליגזז וליעבד מה שאין כן בזבח דגבי תמורה כתיב טוב ברע השווה בעל מום לתם לענין תמורה על כולם נאמר והיה הוא ותמורתו יהיה קדש אבל זבח ראשון אם קדם הקדישו את מומו קדוש קדושת הגוף ואינו יוצא לחולין ליגזז וליעבד כדתנן בבכורות (דף יד.) כל הקדשים שקדם מומן להקדישן נפדה ויליף לה מקראי:'),
#  (('Zevachim', 'חולין, תמורה', 161, 1),
# ...

# %%
import os
import json 

results = []
rashi_dir = "/Users/ephraimmeiri/gitEtc/Rashi Thesis work/Rashi plaintext/json undisputed"

for file in os.listdir(rashi_dir):
    if file == '.DS_Store.json':
        continue
    name = file.split(' - ')[0][9:-5]
    print(name)
    with open(rashi_dir+"/"+file) as f:
        data = json.load(f)
        for daf,d in zip(data['text'],range(len(data['text']))):
            for line,l in zip(daf,range(len(daf))):
                for comment,c in zip(line,range(len(line))):
                    cont = contains_masechet(comment)
                    if cont:
                        results.append([name,d,c,cont,comment])
# Out:
# Bava Kamma
# Sanhedrin
# Bava Batra
# Avodah Zarah
# Makkot
# Yevamot
# Kiddushin
# Niddah
# Pesachim
# Menachot
# Sukkah
# Yoma
# Sotah
# Shevuot
# Temurah
# Gittin
# Berakhot
# Arakhin
# Chullin
# Rosh Hashanah
# Ketubot
# Zevachim
# Megillah
# Beitzah
# Shabbat
# Eruvin
# Bava Metzia
# Chagigah
# Keritot

# %%
import pandas as pd
results_df = pd.DataFrame(results,columns=['Masechet','Daf','Comment','References','Text'])
results_df.to_csv('/Users/ephraimmeiri/Documents/רשי research docs/references subproject/Masechet_references1.csv',index=False)

# %% [markdown]
# Note, unfiltered had 4374
# Removing כלים and ידים brought it down to 4122

# %%
results_df
# Out:
#         Masechet  Daf  Comment   References  \
# 0     Bava Kamma    7        1    בבא מציעא
# 1     Bava Kamma    7        3        חולין
# 2     Bava Kamma    8        0      סנהדרין
# 3     Bava Kamma    8        0       כתובות
# 4     Bava Kamma    8        0  שבת, כתובות
# ...          ...  ...      ...          ...
# 4117     Keritot   47        0        פסחים
# 4118     Keritot   47        0          ב"ק
# 4119     Keritot   48        1          פרה
# 4120     Keritot   50        0        ערכין
# 4121     Keritot   50        0    עבודה זרה
#
#                                                    Text
# 0     שומר חנם - חייב בפשיעה והשואל חייב אפילו באונס...
# 1                                  מדמע - תרומה בחולין:
# 2     לגזיזיה - לכח אגרופו כדאמר בסנהדרין בפ"ק (דף ז...
# 3     אונס ומפתה דממונא הוא - שחמשים כסף לבד הוי קנס...
# 4     תחת נתינה כו' - דבכולהו כתיב או תחת וגמרינן תח...
# ...                                                 ...
# ...

# %%
results_df['Masechet'].value_counts()
# Out:
# Shabbat          473
# Pesachim         296
# Chullin          263
# Eruvin           222
# Zevachim         222
# Sukkah           198
# Sanhedrin        188
# Ketubot          177
# Kiddushin        172
# Menachot         170
# Gittin           153
# Yevamot          137
# Yoma             133
# Sotah            130
# Niddah           127
# Beitzah          125
# Bava Metzia      124
# Berakhot         101
# Bava Kamma       100
# Avodah Zarah      93
# Rosh Hashanah     81
# Keritot           71
# Temurah           69
# Arakhin           67
# Megillah          66
# Shevuot           62
# Chagigah          40
# Makkot            39
# Bava Batra        23
# Name: Masechet, dtype: int64

# %%
results[0]
# Out:
# (('Bava Kamma.json', 'בבא מציעא', 7, 1),
#  'שומר חנם - חייב בפשיעה והשואל חייב אפילו באונסין ושוכר ונושא שכר חייבים בגניבה ואבידה וכ"ש בפשיעה וכולהו כתיבי כדתני בפרק השואל בבבא מציעא (דף צד:) פרשה ראשונה נאמרה בשומר חנם שניה בשומר שכר שלישית בשואל הלכך אבות נינהו ולקמן בעי מאי נינהו תולדות:')

# %% [markdown]
# # בפרק

# %%
def get_results(query):
    results = []
    for file in os.listdir(rashi_dir):
        if file == '.DS_Store.json':
            continue
        name = file.split(' - ')[0][9:-5]
        print(name,end='\t')
        with open(rashi_dir+"/"+file) as f:
            data = json.load(f)
            for daf,d in zip(data['text'],range(len(data['text']))):
                for line,l in zip(daf,range(len(daf))):
                    for comment,c in zip(line,range(len(line))):
                        cont = query(comment)
                        if cont:
                            results.append([name,d,c,cont,comment])
    return results

# %%
masechet_bperek = get_results(contains_masechet_bPerek)
# Out:
# Bava Kamma	Sanhedrin	Bava Batra	Avodah Zarah	Makkot	Yevamot	Kiddushin	Niddah	Pesachim	Menachot	Sukkah	Yoma	Sotah	Shevuot	Temurah	Gittin	Berakhot	Arakhin	Chullin	Rosh Hashanah	Ketubot	Zevachim	Megillah	Beitzah	Shabbat	Eruvin	Bava Metzia	Chagigah	Keritot

# %%
masechet_bperek_df = pd.DataFrame(masechet_bperek,columns=['Masechet','Daf','Comment','References','Text'])
masechet_bperek_df.to_csv('/Users/ephraimmeiri/Documents/רשי research docs/references subproject/Masechet_bPerek_references.csv',index=False)

# %%
len(masechet_bperek)
# Out:
# 202

# %%
masechet_bperek_df['Masechet'].value_counts()
# Out:
# Chullin          22
# Pesachim         20
# Zevachim         15
# Keritot          13
# Ketubot          13
# Menachot         12
# Shabbat          10
# Temurah          10
# Yoma              8
# Shevuot           7
# Gittin            7
# Kiddushin         7
# Bava Kamma        6
# Bava Metzia       6
# Sanhedrin         6
# Berakhot          6
# Eruvin            6
# Sotah             5
# Avodah Zarah      4
# Yevamot           4
# Beitzah           3
# Arakhin           3
# Makkot            2
# Megillah          2
# Niddah            2
# Rosh Hashanah     1
# Bava Batra        1
# Sukkah            1
# Name: Masechet, dtype: int64

# %%
perek_dmasechet = get_results(contains_perek_Dmasechet)
perek_dmasechet_df = pd.DataFrame(perek_dmasechet,columns=['Masechet','Daf','Comment','References','Text'])
perek_dmasechet_df.to_csv('/Users/ephraimmeiri/Documents/רשי research docs/references subproject/Perek_Dmasechet_references.csv',index=False)
# Out:
# Bava Kamma
# Sanhedrin
# Bava Batra
# Avodah Zarah
# Makkot
# Yevamot
# Kiddushin
# Niddah
# Pesachim
# Menachot
# Sukkah
# Yoma
# Sotah
# Shevuot
# Temurah
# Gittin
# Berakhot
# Arakhin
# Chullin
# Rosh Hashanah
# Ketubot
# Zevachim
# Megillah
# Beitzah
# Shabbat
# Eruvin
# Bava Metzia
# Chagigah
# Keritot

# %%
len(perek_dmasechet)
# Out:
# 156

# %%
perek_dmasechet_df['Masechet'].value_counts()
# Out:
# Pesachim         19
# Chullin          15
# Eruvin           12
# Temurah           9
# Shabbat           9
# Menachot          9
# Zevachim          8
# Bava Kamma        8
# Arakhin           7
# Keritot           6
# Sanhedrin         6
# Sukkah            5
# Yoma              5
# Gittin            4
# Yevamot           4
# Shevuot           4
# Berakhot          3
# Sotah             3
# Kiddushin         3
# Rosh Hashanah     3
# Ketubot           2
# Megillah          2
# Beitzah           2
# Avodah Zarah      2
# Bava Metzia       2
# Niddah            2
# Makkot            1
# Bava Batra        1
# Name: Masechet, dtype: int64

# %%
numbers = ["קמא","בתרא","עשירי","תשיעי","שמיני","שביעי","ששי","חמישי","דביעי","שלישי","שני","ראשון"]
def contains_perek_number(text):
    for num in numbers:
        if "בפרק "+num in text:
            return "בפרק "+num
    return None

# %%
def contains_perek(text):
    if "בפרק" in text:
        return True
    else:
        return False

# %%
num_results = get_results(contains_perek_number)
num_results_df = pd.DataFrame(num_results,columns=['Masechet','Daf','Comment','References','Text'])
num_results_df.to_csv('/Users/ephraimmeiri/Documents/רשי research docs/references subproject/Perek_number_references.csv',index=False)
# Out:
# Bava Kamma	Sanhedrin	Bava Batra	Avodah Zarah	Makkot	Yevamot	Kiddushin	Niddah	Pesachim	Menachot	Sukkah	Yoma	Sotah	Shevuot	Temurah	Gittin	Berakhot	Arakhin	Chullin	Rosh Hashanah	Ketubot	Zevachim	Megillah	Beitzah	Shabbat	Eruvin	Bava Metzia	Chagigah	Keritot

# %%
print(len(num_results))
num_results_df['Masechet'].value_counts()
# Out:
# 292
# Pesachim         31
# Zevachim         26
# Chullin          26
# Eruvin           24
# Temurah          13
# Sanhedrin        13
# Keritot          13
# Gittin           11
# Yoma             11
# Bava Kamma       10
# Menachot         10
# Arakhin          10
# Shevuot          10
# Ketubot           9
# Berakhot          8
# Shabbat           8
# Yevamot           7
# Sukkah            7
# Bava Metzia       6
# Sotah             6
# Kiddushin         6
# Rosh Hashanah     6
# Megillah          5
# Beitzah           5
# Avodah Zarah      4
# Niddah            3
# Makkot            2
# Bava Batra        1
# Chagigah          1
# Name: Masechet, dtype: int64

# %%
plain_perek = get_results(contains_perek)
plain_perek_df = pd.DataFrame(plain_perek,columns=['Masechet','Daf','Comment','References','Text'])
plain_perek_df.to_csv('/Users/ephraimmeiri/Documents/רשי research docs/references subproject/Perek_references.csv',index=False)
# Out:
# Bava Kamma	Sanhedrin	Bava Batra	Avodah Zarah	Makkot	Yevamot	Kiddushin	Niddah	Pesachim	Menachot	Sukkah	Yoma	Sotah	Shevuot	Temurah	Gittin	Berakhot	Arakhin	Chullin	Rosh Hashanah	Ketubot	Zevachim	Megillah	Beitzah	Shabbat	Eruvin	Bava Metzia	Chagigah	Keritot

# %%
print(len(plain_perek))
plain_perek_df['Masechet'].value_counts()
# Out:
# 1369
# Zevachim         116
# Yevamot           99
# Chullin           92
# Menachot          87
# Eruvin            86
# Shabbat           83
# Pesachim          80
# Bava Kamma        79
# Ketubot           74
# Sanhedrin         64
# Keritot           58
# Yoma              42
# Bava Metzia       42
# Niddah            41
# Berakhot          40
# Shevuot           36
# Gittin            36
# Temurah           33
# Kiddushin         28
# Sotah             26
# Arakhin           23
# Sukkah            23
# Avodah Zarah      19
# Megillah          14
# Beitzah           14
# Rosh Hashanah     13
# Makkot             8
# Bava Batra         7
# Chagigah           6
# Name: Masechet, dtype: int64

# %%
type(plain_perek_df['Masechet'].value_counts())
# Out:
# pandas.core.series.Series

# %%
def contains_Bmasechet(text):
    if "במסכת" in text:
        return True
    else:
        return False
bMasechet_results = get_results(contains_Bmasechet)
bMasechet_results_df = pd.DataFrame(bMasechet_results,columns=['Masechet','Daf','Comment','References','Text'])
bMasechet_results_df.to_csv('/Users/ephraimmeiri/Documents/רשי research docs/references subproject/Bmasechet_references.csv',index=False)
# Out:
# Bava Kamma	Sanhedrin	Bava Batra	Avodah Zarah	Makkot	Yevamot	Kiddushin	Niddah	Pesachim	Menachot	Sukkah	Yoma	Sotah	Shevuot	Temurah	Gittin	Berakhot	Arakhin	Chullin	Rosh Hashanah	Ketubot	Zevachim	Megillah	Beitzah	Shabbat	Eruvin	Bava Metzia	Chagigah	Keritot

# %%
print(len(bMasechet_results))
# Out:
# 1108

# %%
perek_names =[]
with open('/Users/ephraimmeiri/Documents/רשי research docs/references subproject/perakim_names1.txt') as f:
    data = f.read()
    perek_names = data.split(', ')
def contains_perek_name(text):
    for name in perek_names:
        if "ב"+name in text:
            return name
    return None

# %%
perek_name_results = get_results(contains_perek_name)
perek_name_results_df = pd.DataFrame(perek_name_results,columns=['Masechet','Daf','Comment','References','Text'])
perek_name_results_df.to_csv('/Users/ephraimmeiri/Documents/רשי research docs/references subproject/Perek_name_references.csv',index=False)
# Out:
# Bava Kamma	Sanhedrin	Bava Batra	Avodah Zarah	Makkot	Yevamot	Kiddushin	Niddah	Pesachim	Menachot	Sukkah	Yoma	Sotah	Shevuot	Temurah	Gittin	Berakhot	Arakhin	Chullin	Rosh Hashanah	Ketubot	Zevachim	Megillah	Beitzah	Shabbat	Eruvin	Bava Metzia	Chagigah	Keritot

# %%
print(len(perek_name_results))
perek_name_results_df['Masechet'].value_counts()
# Out:
# 2457
# Pesachim         194
# Chullin          187
# Zevachim         183
# Shabbat          178
# Sanhedrin        147
# Sukkah           143
# Bava Metzia      130
# Bava Kamma       130
# Gittin           102
# Eruvin           100
# Menachot          94
# Beitzah           92
# Yevamot           91
# Yoma              88
# Avodah Zarah      76
# Ketubot           70
# Niddah            64
# Kiddushin         60
# Berakhot          50
# Sotah             44
# Temurah           37
# Arakhin           34
# Megillah          29
# Shevuot           29
# Bava Batra        26
# Rosh Hashanah     23
# Makkot            19
# Chagigah          19
# Keritot           18
# Name: Masechet, dtype: int64

# %%
comparison_df = pd.concat([results_df['Masechet'].value_counts(),
                           plain_perek_df['Masechet'].value_counts(),
                           num_results_df['Masechet'].value_counts(),
                           perek_dmasechet_df['Masechet'].value_counts(),
                           masechet_bperek_df['Masechet'].value_counts(),
                           bMasechet_results_df['Masechet'].value_counts(),
                           perek_name_results_df['Masechet'].value_counts()],
                           axis=1,sort=False,
                           keys=['Masechet','Perek','Number','Perek_Dmasechet','Masechet_bPerek','bMasechet','perek_name'])

# %%
comparison_df
# Out:
#                Masechet  Perek  Number  Perek_Dmasechet  Masechet_bPerek  \
# Shabbat             473     83       8              9.0             10.0
# Pesachim            296     80      31             19.0             20.0
# Chullin             263     92      26             15.0             22.0
# Eruvin              222     86      24             12.0              6.0
# Zevachim            222    116      26              8.0             15.0
# Sukkah              198     23       7              5.0              1.0
# Sanhedrin           188     64      13              6.0              6.0
# Ketubot             177     74       9              2.0             13.0
# Kiddushin           172     28       6              3.0              7.0
# Menachot            170     87      10              9.0             12.0
# Gittin              153     36      11              4.0              7.0
# Yevamot             137     99       7              4.0              4.0
# ...

# %%
comparison_df['masechet/perek']= (comparison_df['Masechet']+comparison_df['bMasechet'])/(comparison_df['perek_name']+comparison_df['Perek']+comparison_df['Number'])

# %%
comparison_df.sort_values(by='masechet/perek',ascending=False,inplace=True)
comparison_df
# Out:
#                Masechet  Perek  Number  Perek_Dmasechet  Masechet_bPerek  \
# Chagigah             40      6       1              NaN              NaN
# Rosh Hashanah        81     13       6              3.0              1.0
# Megillah             66     14       5              2.0              2.0
# Kiddushin           172     28       6              3.0              7.0
# Shabbat             473     83       8              9.0             10.0
# Sotah               130     26       6              3.0              5.0
# Ketubot             177     74       9              2.0             13.0
# Yoma                133     42      11              5.0              8.0
# Makkot               39      8       2              1.0              2.0
# Berakhot            101     40       8              3.0              6.0
# Shevuot              62     36      10              4.0              7.0
# Niddah              127     41       3              2.0              2.0
# ...

# %%
comparison_df['Masechet/total'] = comparison_df['Masechet']/len(results_df)

# %%
comparison_df.sort_values(by='Masechet/total',ascending=False)
# Out:
#                Masechet  Perek  Number  Perek_Dmasechet  Masechet_bPerek  \
# Shabbat             473     83       8              9.0             10.0
# Pesachim            296     80      31             19.0             20.0
# Chullin             263     92      26             15.0             22.0
# Eruvin              222     86      24             12.0              6.0
# Zevachim            222    116      26              8.0             15.0
# Sukkah              198     23       7              5.0              1.0
# Sanhedrin           188     64      13              6.0              6.0
# Ketubot             177     74       9              2.0             13.0
# Kiddushin           172     28       6              3.0              7.0
# Menachot            170     87      10              9.0             12.0
# Gittin              153     36      11              4.0              7.0
# Yevamot             137     99       7              4.0              4.0
# ...

# %%
comparison_df.to_csv('/Users/ephraimmeiri/Documents/רשי research docs/references subproject/Comparison.csv')

# %%
masecta_ref_counts = results_df['References'].value_counts()
with open('/Users/ephraimmeiri/Documents/רשי research docs/references subproject/masechta_name_ref_counts.txt','w') as f:
    f.write(masecta_ref_counts.to_string())

# %%
bMasechet_ref_counts = bMasechet_results_df['References'].value_counts()
with open('/Users/ephraimmeiri/Documents/רשי research docs/references subproject/bMasechet_name_ref_counts.txt','w') as f:
    f.write(bMasechet_ref_counts.to_string())

# %%
print(bMasechet_results_df['Text'][0].split('במסכת')[0])
print(bMasechet_results_df['Text'][0].split('במסכת')[1])
print(bMasechet_results_df['Text'][0].split('במסכת')[1].split(' ')[1])
# Out:
# ולר"א דמחייב תרתי כו' - דאי עביד אב ותולדה דידיה מחייב תרתי חטאות במס' כריתות בפ' אמרו לו (כריתות דף טז.) כולהו אבות מלאכות ממשכן גמרינן להו
#  שבת (דף מט:):
# שבת

# %%
# find all words that appear to the right of במסכת
neighbors = dict()
for text in bMasechet_results_df['Text']:
    word = text.split("במסכת")[1].split(" ")[1]
    neighbors[word] = neighbors.get(word,0)+1
with open('/Users/ephraimmeiri/Documents/רשי research docs/references subproject/bMasechet_neighbors.txt','w') as f:
    for word,count in neighbors.items():
        f.write(word+'\t'+str(count)+'\n')
# neighbors

# %%
name_neighbors = dict()
for text in results['Text']:
    word = text.split("במסכת")[0].split(" ")[1]
    name_neighbors[word] = name_neighbors.get(word,0)+1
with open('/Users/ephraimmeiri/Documents/רשי research docs/references subproject/namedMasechet_neighbors.txt','w') as f:
    for word,count in name_neighbors.items():
        f.write(word+'\t'+str(count)+'\n')

# %% [markdown]
# # Only Bavli

# %% [markdown]
# Queries:
# דמסכת
# במסכת <שם
# בפרק <שם
# בפרק N
# בפרק <?> דמסכת
# במסכת <?> בפרק

# %%
import os
import json
import pandas as pd
rashi_dir= '/Users/ephraimmeiri/gitEtc/Rashi Thesis work/Rashi plaintext/json undisputed'

# %%
masechtot_bavli =[]
with open('/Users/ephraimmeiri/Documents/רשי research docs/references subproject/input/שמות מסכתות בבלי.txt') as f:
    data = f.read()
    masechtot_bavli = data.split(', ')

# %%
def contains_perek_Dmasechet2(text):
    results= None
    for masechet in masechtot_bavli:
        if "ד"+masechet in text and "פרק" in text:
            if results:
                results+=", "
                # print("Multi")
            else:
                results=""
            results+=masechet
    return results
perek_dmasechet = get_results(contains_perek_Dmasechet2)
# Out:
# Bava Kamma	Sanhedrin	Bava Batra	Avodah Zarah	Makkot	Yevamot	Kiddushin	Niddah	Pesachim	Menachot	Sukkah	Yoma	Sotah	Shevuot	Temurah	Gittin	Berakhot	Arakhin	Chullin	Rosh Hashanah	Ketubot	Zevachim	Megillah	Beitzah	Shabbat	Eruvin	Bava Metzia	Chagigah	Keritot

# %%
def contains_masechet_bPerek(text):
    results= None
    for masechet in masechtot_bavli:
        if "ב"+masechet+" בפרק" in text:
            if results:
                results+=", "
                # print("Multi")
            else:
                results=""
            results+=masechet
    return results
masechet_bperek = get_results(contains_masechet_bPerek)
# Out:
# Bava Kamma	Sanhedrin	Bava Batra	Avodah Zarah	Makkot	Yevamot	Kiddushin	Niddah	Pesachim	Menachot	Sukkah	Yoma	Sotah	Shevuot	Temurah	Gittin	Berakhot	Arakhin	Chullin	Rosh Hashanah	Ketubot	Zevachim	Megillah	Beitzah	Shabbat	Eruvin	Bava Metzia	Chagigah	Keritot

# %%
def contains_masechet(text):
    results= None
    for masechet in masechtot_bavli:
        if "ב"+masechet in text:
            if results:
                results+=", "
                # print("Multi")
            else:
                results=""
            results+=masechet
    return results
bMasechet = get_results(contains_masechet)
# Out:
# Bava Kamma	Sanhedrin	Bava Batra	Avodah Zarah	Makkot	Yevamot	Kiddushin	Niddah	Pesachim	Menachot	Sukkah	Yoma	Sotah	Shevuot	Temurah	Gittin	Berakhot	Arakhin	Chullin	Rosh Hashanah	Ketubot	Zevachim	Megillah	Beitzah	Shabbat	Eruvin	Bava Metzia	Chagigah	Keritot

# %%
perek_names =[]
with open('/Users/ephraimmeiri/Documents/רשי research docs/references subproject/input/perakim_names1.txt') as f:
    data = f.read()
    perek_names = data.split(', ')
def contains_perek(text):
    for name in perek_names:
        if "ב"+name in text:
            return name
plain_perek = get_results(contains_perek)
# Out:
# Bava Kamma	Sanhedrin	Bava Batra	Avodah Zarah	Makkot	Yevamot	Kiddushin	Niddah	Pesachim	Menachot	Sukkah	Yoma	Sotah	Shevuot	Temurah	Gittin	Berakhot	Arakhin	Chullin	Rosh Hashanah	Ketubot	Zevachim	Megillah	Beitzah	Shabbat	Eruvin	Bava Metzia	Chagigah	Keritot

# %%
numbers = ["קמא","בתרא","עשירי","תשיעי","שמיני","שביעי","ששי","חמישי","דביעי","שלישי","שני","ראשון"]
def contains_number(text):
    for num in numbers:
        if "בפרק "+num in text:
            return "בפרק "+num
    return None
num_results = get_results(contains_number)

# %%
num_results_df = pd.DataFrame(num_results,columns=['Masechet','Daf','Comment','References','Text'])
perek_df= pd.DataFrame(plain_perek,columns=['Masechet','Daf','Comment','References','Text'])
bMasechet_df = pd.DataFrame(bMasechet,columns=['Masechet','Daf','Comment','References','Text'])

# %%
comparison_df2= pd.concat([bMasechet_results_df['Masechet'].value_counts(),
                            plain_perek_df['Masechet'].value_counts(),
                            num_results_df['Masechet'].value_counts(),
                            perek_dmasechet_df['Masechet'].value_counts(),
                            masechet_bperek_df['Masechet'].value_counts(),
                            bMasechet_results_df['Masechet'].value_counts(),
                            perek_name_results_df['Masechet'].value_counts()],
                            axis=1,sort=False,
                            keys=['Masechet','Perek','Number','Perek_Dmasechet','Masechet_bPerek','bMasechet','perek_name'])

# %% [markdown]
# # Mishnah Perek References

# %%
pirkei_mishna=[]
with open("/Users/ephraimmeiri/Documents/רשי research docs/references subproject/input/perakim_names_MishnaOnly.txt",'r') as f:
    data = f.read()
    pirkei_mishna = data.split(', ')
def contains_mishna_perek(text):
    for name in pirkei_mishna:
        if "בפרק "+name in text:
            return  str("בפרק "+name)
        elif "ב"+name in text:
            return name
    return None
mishna_perek = get_results(contains_mishna_perek)
# Out:
# Bava Kamma	Sanhedrin	Bava Batra	Avodah Zarah	Makkot	Yevamot	Kiddushin	Niddah	Pesachim	Menachot	Sukkah	Yoma	Sotah	Shevuot	Temurah	Gittin	Berakhot	Arakhin	Chullin	Rosh Hashanah	Ketubot	Zevachim	Megillah	Beitzah	Shabbat	Eruvin	Bava Metzia	Chagigah	Keritot

# %%
mishna_perek_df = pd.DataFrame(mishna_perek,columns=['Masechet','Daf','Comment','References','Text'])
mishna_perek_df
# Out:
#         Masechet  Daf  Comment   References  \
# 0     Bava Kamma    3        0         גופה
# 1     Bava Kamma    9        0         גדיש
# 2     Bava Kamma   18        1           שק
# 3     Bava Kamma   25        0           שק
# 4     Bava Kamma   26        0    בפרק כיצד
# ...          ...  ...      ...          ...
# 1082     Keritot   10        1  בפרק התרומה
# 1083     Keritot   21        1           שק
# 1084     Keritot   23        0    בפרק כיצד
# 1085     Keritot   29        0          בגד
# 1086     Keritot   51        0           שק
#
#                                                    Text
# 0                    נגיפה - שדחפה בגופה והזיקה בכוונה:
# 1     לפטור בו את הטמון - שאם היו בגדים טמונים בגדיש...
# 2     שייר טמון - דהוה ליה למתני חומר בשור ובור מבאש...
# 3                       בשקדם וזכה בו אחר - לאחר שהזיק:
# 4     רבי טרפון היא דאמר - לקמן בפרק כיצד (בבא קמא ד...
# ...                                                 ...
# ...

# %%
mishna_perek_df.to_csv('/Users/ephraimmeiri/Documents/רשי research docs/references subproject/Mishna_Perek_references.csv',index=False)

# %% [markdown]
# There appear to be 2 real examples:
# Menachot	101	0	בפרק מעות שנמצאו	ז' דברים - במסכת שקלים בפרק מעות שנמצאו:
# Sanhedrin   9   0   בפרק שלש ארצות  רבי חייא חזייה כו' - לא איתפרש לן מאי בעיא הכא ונראה בעיני דהא אתא לאשמעינן אף על גב דרבי חייא תלמידו דרבי הוה ובמקומו דר' הוה לא חלק לו כבוד לרבי מלהפריש זה מן האיסור דלענין אפרושי מאיסורא אין כאן מורה הלכה לפני רבו כדאמרינן פרק הדר עם הנכרי (עירובין סג.) ובמס' שביעית ירושלמי בפרק שלש ארצות מצאתי בההוא עובדא דההוא דקאי בבית הקברות דלא גרסינן ביה רבי חייא אלא רבי הוה ושני דברים הללו ראה רבי בעכו דמי ביצים אין מכשירין והאי ולא גרסינן דהוה קאי בבית הקברות אלא בעכו שבה ארץ ישראל ויש בה ארץ העמים וראה אותן העומדים בגבול ארץ ישראל שהיו מגבלין עיסותיהן בטומאה ותמה עד שאמרו לו תלמיד אחד בא לכאן כו' וחזר וראה אותו כהן עומד בקצת העיר שחוץ לגבול ארץ ישראל אמר לו והרי הוא זה ארץ העמים שגזרו עליה טומאה כבית הקברות ואמר ליה לאו בן איש כהן פלוני אתה כו' ולכך נשנו מעשים הללו זה אצל זה:

# %%
numbers = ["קמא","בתרא","עשירי","תשיעי","שמיני","שביעי","ששי","חמישי","דביעי","שלישי","שני","ראשון"]

def contains_DMasechet(text):
    for masechet in masechtot_bavli:
        if "ד"+masechet in text:
            splt = text.split("ד"+masechet)
            if len(splt)<2:
                print("SHORT ",text)
                return masechet
            if(len(splt[0].split(" "))<2):
                prev = ""
            else:
                prev = splt[0].split(" ")[-2]
            if prev in numbers:
                return None
            if(len(splt[1].split(" "))<2):
                next = ""
            else:
                next = splt[1].split(" ")[1]
            return str(prev+" "+masechet+" "+next)
    return None

# %%
sample = "הכא מאי - תולדות דשבת הוי כאבות תולדות דטומאה לא הוי כאבות והכא תולדות דנזקין מאי מי אמרינן תולדות כיוצא בהן לא שנא אב לש תולדה אם הזיק משלם או דלמא לא:"
for masechet in masechtot_bavli:
    if "ד"+masechet in sample:
        splt = sample.split("ד"+masechet)
        print(masechet)
        for s in splt:
            print(s)
# Out:
# שבת
# הכא מאי - תולדות
#  הוי כאבות תולדות דטומאה לא הוי כאבות והכא תולדות דנזקין מאי מי אמרינן תולדות כיוצא בהן לא שנא אב לש תולדה אם הזיק משלם או דלמא לא:

# %%
prev = splt[0].split(" ")[-2]
print(prev)
print(splt[1].split(" ")[1])
# Out:
# תולדות
# הוי

# %%
dMasechet = get_results(contains_DMasechet)
# Out:
# Bava Kamma	Sanhedrin	Bava Batra	Avodah Zarah	Makkot	Yevamot	Kiddushin	Niddah	Pesachim	Menachot	Sukkah	Yoma	Sotah	Shevuot	Temurah	Gittin	Berakhot	Arakhin	Chullin	Rosh Hashanah	Ketubot	Zevachim	Megillah	Beitzah	Shabbat	Eruvin	Bava Metzia	Chagigah	Keritot

# %%
dMasechet_df = pd.DataFrame(dMasechet,columns=['Masechet','Daf','Comment','References','Text'])
dMasechet_df.to_csv('/Users/ephraimmeiri/Documents/רשי research docs/references subproject/Dmasechet_references.csv',index=False)

# %%
len(dMasechet)
# Out:
# 659
